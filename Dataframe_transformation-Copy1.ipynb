# %% [markdown]
# # Various Methods to Transform DataFrames

# %%
import pandas as pd

# %%
pd.read_csv("ml-100k/u.data",sep='\t',)
# Out:
#        196   242  3  881250949
# 0      186   302  3  891717742
# 1       22   377  1  878887116
# 2      244    51  2  880606923
# 3      166   346  1  886397596
# 4      298   474  4  884182806
# ...    ...   ... ..        ...
# 99994  880   476  3  880175444
# 99995  716   204  5  879795543
# 99996  276  1090  1  874795795
# 99997   13   225  2  882399156
# 99998   12   203  3  879959583
#
# [99999 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_csv("Crime_Data_from_2020_to_Present.csv")
print(df.columns)
df.head()
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 3  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
# 4  200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30     1
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2  N Hollywood         1543         2     745
# 3      Mission         1998         2     740
# 4      Central          163         1     121
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO  Adult Other
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC  Invest Cont
# 2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC  Invest Cont
# 3  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC  Invest Cont
# 4                                     RAPE, FORCIBLE  ...     IC  Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    624.0      NaN       NaN      NaN
# 1    624.0      NaN       NaN      NaN
# 2    745.0    998.0       NaN      NaN
# 3    740.0      NaN       NaN      NaN
# 4    121.0    998.0       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1100 W  39TH                         PL          NaN  34.0141 -118.2978
# 1    700 S  HILL                         ST          NaN  34.0459 -118.2545
# 2   5400    CORTEEN                      PL          NaN  34.1685 -118.4019
# 3  14400    TITUS                        ST          NaN  34.2198 -118.4468
# 4                           700 S  BROADWAY          NaN  34.0452 -118.2534
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Inspect Column types
# - `object` indicates a string type

# %%
df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %% [markdown]
# ## Transform dataframes with basic arithmetic
# - works best if the columns are all numerical
# - string columns can have interesting results

# %%
(df*2).head()
# Out:
#        DR_NO                                     Date Rptd  \
# 0   20608936  01/08/2020 12:00:00 AM01/08/2020 12:00:00 AM
# 1  380202172  01/02/2020 12:00:00 AM01/02/2020 12:00:00 AM
# 2  383003010  01/01/2020 12:00:00 AM01/01/2020 12:00:00 AM
# 3  383842538  01/01/2020 12:00:00 AM01/01/2020 12:00:00 AM
# 4  400201002  01/02/2020 12:00:00 AM01/02/2020 12:00:00 AM
#
#                                        DATE OCC  TIME OCC  AREA  \
# 0  01/08/2020 12:00:00 AM01/08/2020 12:00:00 AM      4460     6
# 1  01/01/2020 12:00:00 AM01/01/2020 12:00:00 AM       660     2
# 2  01/01/2020 12:00:00 AM01/01/2020 12:00:00 AM      3460    30
# 3  01/01/2020 12:00:00 AM01/01/2020 12:00:00 AM       830    38
# 4  01/01/2020 12:00:00 AM01/01/2020 12:00:00 AM        60     2
#
#                 AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0      SouthwestSouthwest          754         4    1248
# 1          CentralCentral          326         4    1248
# 2  N HollywoodN Hollywood         3086         4    1490
# 3          MissionMission         3996         4    1480
# 4          CentralCentral          326         2     242
#
#                                          Crm Cd Desc  ... Status  \
# 0   BATTERY - SIMPLE ASSAULTBATTERY - SIMPLE ASSAULT  ...   AOAO
# 1   BATTERY - SIMPLE ASSAULTBATTERY - SIMPLE ASSAULT  ...   ICIC
# 2  VANDALISM - MISDEAMEANOR ($399 OR UNDER)VANDAL...  ...   ICIC
# 3  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...   ICIC
# 4                       RAPE, FORCIBLERAPE, FORCIBLE  ...   ICIC
#
#               Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult OtherAdult Other   1248.0      NaN       NaN      NaN
# 1  Invest ContInvest Cont   1248.0      NaN       NaN      NaN
# 2  Invest ContInvest Cont   1490.0   1996.0       NaN      NaN
# 3  Invest ContInvest Cont   1480.0      NaN       NaN      NaN
# 4  Invest ContInvest Cont    242.0   1996.0       NaN      NaN
#
#                                             LOCATION Cross Street      LAT  \
# 0  1100 W  39TH                         PL1100 W ...          NaN  68.0282
# 1  700 S  HILL                         ST700 S  H...          NaN  68.0918
# 2  5400    CORTEEN                      PL5400   ...          NaN  68.3370
# 3  14400    TITUS                        ST14400 ...          NaN  68.4396
# 4                     700 S  BROADWAY700 S  BROADWAY          NaN  68.0904
#
#         LON
# 0 -236.5956
# 1 -236.5090
# 2 -236.8038
# 3 -236.8936
# 4 -236.5068
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Adding gives an error
# - because it doesn't know what to do with the string columns

# %%
df+2 #run to see the error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/2t/mwt3_s7x77j3l_mp55rnmbs00000gq/T/ipykernel_67255/2632019974.py in <module>
# ----> 1 df+2 #run to see the error
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __add__(self, other)
#      90     @unpack_zerodim_and_defer("__add__")
#      91     def __add__(self, other):
# ---> 92         return self._arith_method(other, operator.add)
#      93
#      94     @unpack_zerodim_and_defer("__radd__")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    6891             # i.e. scalar, faster than checking np.ndim(right) == 0
#    6892             with np.errstate(all="ignore"):
# -> 6893                 bm = self._mgr.apply(array_op, right=right)
#    6894             return type(self)(bm)
#    6895
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     323             try:
#     324                 if callable(f):
# --> 325                     applied = b.apply(f, **kwargs)
#     326                 else:
#     327                     applied = getattr(b, f)(**kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     379         """
#     380         with np.errstate(all="ignore"):
# --> 381             result = func(self.values, **kwargs)
#     382
#     383         return self._split_op_result(result)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     129
#     130         if mask.any():
# --> 131             result[mask] = op(xrav[mask], y)
#     132
#     133     np.putmask(result, ~mask, np.nan)
#
# TypeError: can only concatenate str (not "int") to str

# %%
df.div
df.mul
df.sub
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 3       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# 4       200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30
# ...           ...                     ...                     ...       ...
# 481749  221906145  02/23/2022 12:00:00 AM  02/23/2022 12:00:00 AM      1210
# 481750  221108224  04/23/2022 12:00:00 AM  04/23/2022 12:00:00 AM       100
# 481751  221005507  02/10/2022 12:00:00 AM  02/09/2022 12:00:00 AM      1530
# 481752  221105477  02/10/2022 12:00:00 AM  02/08/2022 12:00:00 AM      2000
# 481753  221605448  02/15/2022 12:00:00 AM  02/14/2022 12:00:00 AM      1800
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          3    Southwest          377         2     624
# 1          1      Central          163         2     624
# 2         15  N Hollywood         1543         2     745
# 3         19      Mission         1998         2     740
# 4          1      Central          163         1     121
# ...      ...          ...          ...       ...     ...
# 481749    19      Mission         1985         1     421
# 481750    11    Northeast         1189         1     210
# 481751    10  West Valley         1024         1     510
# 481752    11    Northeast         1171         1     510
# 481753    16     Foothill         1613         1     331
#
#                                               Crm Cd Desc  ... Status  \
# 0                                BATTERY - SIMPLE ASSAULT  ...     AO
# 1                                BATTERY - SIMPLE ASSAULT  ...     IC
# 2                VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 3       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 4                                          RAPE, FORCIBLE  ...     IC
# ...                                                   ...  ...    ...
# 481749                 THEFT FROM MOTOR VEHICLE - ATTEMPT  ...     IC
# 481750                                            ROBBERY  ...     IC
# 481751                                   VEHICLE - STOLEN  ...     IC
# 481752                                   VEHICLE - STOLEN  ...     IC
# 481753  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...     IC
#
#         Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0       Adult Other    624.0      NaN       NaN      NaN
# 1       Invest Cont    624.0      NaN       NaN      NaN
# 2       Invest Cont    745.0    998.0       NaN      NaN
# 3       Invest Cont    740.0      NaN       NaN      NaN
# 4       Invest Cont    121.0    998.0       NaN      NaN
# ...             ...      ...      ...       ...      ...
# 481749  Invest Cont    421.0    998.0       NaN      NaN
# 481750  Invest Cont    210.0      NaN       NaN      NaN
# 481751  Invest Cont    510.0      NaN       NaN      NaN
# 481752  Invest Cont    510.0      NaN       NaN      NaN
# 481753  Invest Cont    331.0      NaN       NaN      NaN
#
#                                         LOCATION Cross Street      LAT  \
# 0        1100 W  39TH                         PL          NaN  34.0141
# 1         700 S  HILL                         ST          NaN  34.0459
# 2        5400    CORTEEN                      PL          NaN  34.1685
# 3       14400    TITUS                        ST          NaN  34.2198
# 4                                700 S  BROADWAY          NaN  34.0452
# ...                                          ...          ...      ...
# 481749   8400    VAN NUYS                     BL          NaN  34.2229
# 481750   3200 N  FIGUEROA                     ST          NaN  34.0854
# 481751  18800    SHERMAN                      WY          NaN  34.2011
# 481752   4000    FOUNTAIN                     AV          NaN  34.0958
# 481753  12700    VAN NUYS                     BL          NaN  34.2755
#
#              LON
# 0      -118.2978
# 1      -118.2545
# 2      -118.4019
# 3      -118.4468
# 4      -118.2534
# ...          ...
# 481749 -118.4487
# 481750 -118.2204
# 481751 -118.5426
# 481752 -118.2787
# 481753 -118.4092
#
# [481754 rows x 28 columns]>

# %% [markdown]
# ## when we subset to numerical columns, the addition works

# %%
(df[['TIME OCC', 'AREA']]+2).head()
# Out:
#    TIME OCC  AREA
# 0      2232     5
# 1       332     3
# 2      1732    17
# 3       417    21
# 4        32     3

# %% [markdown]
# # Add new columns to a dataframe

# %%
df['AREA_OVER_5'] = df['AREA'] > 5
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 3  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
# 4  200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30     1
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2  N Hollywood         1543         2     745
# 3      Mission         1998         2     740
# 4      Central          163         1     121
#
#                                          Crm Cd Desc  ...  Status Desc  \
# 0                           BATTERY - SIMPLE ASSAULT  ...  Adult Other
# 1                           BATTERY - SIMPLE ASSAULT  ...  Invest Cont
# 2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...  Invest Cont
# 3  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...  Invest Cont
# 4                                     RAPE, FORCIBLE  ...  Invest Cont
#
#    Crm Cd 1 Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# 0     624.0      NaN      NaN       NaN
# 1     624.0      NaN      NaN       NaN
# 2     745.0    998.0      NaN       NaN
# 3     740.0      NaN      NaN       NaN
# 4     121.0    998.0      NaN       NaN
#
#                                    LOCATION  Cross Street      LAT       LON  \
# 0   1100 W  39TH                         PL           NaN  34.0141 -118.2978
# 1    700 S  HILL                         ST           NaN  34.0459 -118.2545
# 2   5400    CORTEEN                      PL           NaN  34.1685 -118.4019
# 3  14400    TITUS                        ST           NaN  34.2198 -118.4468
# 4                           700 S  BROADWAY           NaN  34.0452 -118.2534
#
#   AREA_OVER_5
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Add new columns using  arithmetic operations

# %%
df['Times10'] = df['TIME OCC']*10
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 3  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
# 4  200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30     1
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2  N Hollywood         1543         2     745
# 3      Mission         1998         2     740
# 4      Central          163         1     121
#
#                                          Crm Cd Desc  ... Crm Cd 1  Crm Cd 2  \
# 0                           BATTERY - SIMPLE ASSAULT  ...    624.0       NaN
# 1                           BATTERY - SIMPLE ASSAULT  ...    624.0       NaN
# 2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...    745.0     998.0
# 3  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...    740.0       NaN
# 4                                     RAPE, FORCIBLE  ...    121.0     998.0
#
#   Crm Cd 3 Crm Cd 4                                  LOCATION Cross Street  \
# 0      NaN      NaN   1100 W  39TH                         PL          NaN
# 1      NaN      NaN    700 S  HILL                         ST          NaN
# 2      NaN      NaN   5400    CORTEEN                      PL          NaN
# 3      NaN      NaN  14400    TITUS                        ST          NaN
# 4      NaN      NaN                           700 S  BROADWAY          NaN
#
#        LAT       LON AREA_OVER_5 Times10
# 0  34.0141 -118.2978       False   22300
# 1  34.0459 -118.2545       False    3300
# 2  34.1685 -118.4019        True   17300
# 3  34.2198 -118.4468        True    4150
# 4  34.0452 -118.2534       False     300
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Create discrete bins from age column
# - look up `cut` and `qcut`
# - https://pandas.pydata.org/docs/reference/api/pandas.qcut.html

# %%
cut_labels_4 = ['0-5', '6-10', '11-20','21+']
cut_bins = [5, 10, 20,35,50]
df['cut_'] = pd.cut(df['AREA'], bins=cut_bins, labels=cut_labels_4)
df[['AREA','cut_']].head()
# Out:
#    AREA  cut_
# 0     3   NaN
# 1     1   NaN
# 2    15  6-10
# 3    19  6-10
# 4     1   NaN

# %% [markdown]
# ### Strings columns can also be maniplated
# - use str method to access string method
# - see Pandas str methods https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html

# %%
df['Crm Cd Desc'].str.startswith('B').head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Crm Cd Desc, dtype: bool

# %%
df['Crm Cd Desc'].str.replace("BATTERY",'XXXXXX').head()
# Out:
# 0                              XXXXXX - SIMPLE ASSAULT
# 1                              XXXXXX - SIMPLE ASSAULT
# 2             VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 3    VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 4                                       RAPE, FORCIBLE
# Name: Crm Cd Desc, dtype: object

# %%
df['Crm Cd Desc'].str.split("-").head()
# Out:
# 0                          [BATTERY ,  SIMPLE ASSAULT]
# 1                          [BATTERY ,  SIMPLE ASSAULT]
# 2          [VANDALISM ,  MISDEAMEANOR ($399 OR UNDER)]
# 3    [VANDALISM ,  FELONY ($400 & OVER, ALL CHURCH ...
# 4                                     [RAPE, FORCIBLE]
# Name: Crm Cd Desc, dtype: object

# %%
df['Crm Cd Desc'].str.split("-").str[-1].head()  # get the last element of string split
# Out:
# 0                                  SIMPLE ASSAULT
# 1                                  SIMPLE ASSAULT
# 2                    MISDEAMEANOR ($399 OR UNDER)
# 3     FELONY ($400 & OVER, ALL CHURCH VANDALISMS)
# 4                                  RAPE, FORCIBLE
# Name: Crm Cd Desc, dtype: object

# %% [markdown]
# # Add columns using apply method
#
# - functions to manipulate a column or mutiple columns using lambda functions
# - lambda functions allow us to define functions on the fly
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html#row-or-column-wise-function-application

# %%
df['AREA'] = df['Part 1-2'].apply(lambda x: x < 0.2)  #apply on a single column
df[['Part 1-2','AREA']].head()
# Out:
#    Part 1-2   AREA
# 0         2  False
# 1         2  False
# 2         2  False
# 3         2  False
# 4         1  False

# %% [markdown]
# ### Lambda functions can have multiple arguments
# - note the axis argument. axis indicates to apply the function is row wise on dataframe.
# - apply is used on the entire dataframe not single columns like in the previous example

# %% [markdown]
# ## Some functions are too complex to be used in a lambda function
# - we can define a function seperately and apply it
