# %% [markdown]
# # Dataframe indexing
# - Indexing to get selection or filters of the data
# - row index manipulation
# - https://pandas.pydata.org/docs/user_guide/indexing.html

# %%
import pandas as pd

# %%
df = pd.read_csv("healthcare-dataset-stroke-data.csv") 
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %% [markdown]
# ## The dataframe has a native numerical index
# - the native index is just a range index
# - the data seems have its own the `id` column, but we shall ignore that

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5110, step=1)

# %% [markdown]
# ## `iloc` does numerical indexing of the rows
# - take first 30 rows

# %%
df.iloc[0:5]
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.iloc[100:200] # rows 5 to 10
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 100  12363    Male  64.0             0              1          Yes
# 101  63973  Female  77.0             0              0          Yes
# 102  45277  Female  74.0             0              0          Yes
# 103   4712  Female  81.0             0              1          Yes
# 104  33175  Female  57.0             0              0          Yes
# ..     ...     ...   ...           ...            ...          ...
# 195  64373    Male  59.0             0              0          Yes
# 196  58267    Male  70.0             1              0          Yes
# 197  35684    Male  69.0             0              0          Yes
# 198  18937    Male  79.0             0              0          Yes
# 199    491  Female  74.0             0              0          Yes
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 100       Govt_job          Urban              74.10  28.8          Unknown
# 101       Govt_job          Rural             190.32  31.4     never smoked
# 102        Private          Rural             231.61  34.6  formerly smoked
# 103  Self-employed          Rural              78.70  19.4          Unknown
# 104       Govt_job          Urban             110.52  28.5          Unknown
# ..             ...            ...                ...   ...              ...
# 195        Private          Urban             200.62  35.8  formerly smoked
# 196        Private          Rural             242.52  45.5  formerly smoked
# 197        Private          Rural              93.81  28.5          Unknown
# 198        Private          Rural             114.77   NaN  formerly smoked
# 199  Self-employed          Urban              74.96  26.6     never smoked
#
#      stroke
# 100       1
# 101       1
# 102       1
# 103       1
# 104       1
# ..      ...
# 195       1
# 196       1
# 197       1
# 198       1
# 199       1
#
# [100 rows x 12 columns]

# %%
df.iloc[300:].head() # rows from 300 and beyond
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 300  65199  Female  53.0             0              0          Yes
# 301  43454  Female  78.0             0              0           No
# 302   7282    Male  44.0             0              0          Yes
# 303  18518    Male  66.0             0              0          Yes
# 304  41648    Male  27.0             0              0          Yes
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 300  Self-employed          Urban              81.51  28.5          Unknown
# 301  Self-employed          Urban             137.74  34.9  formerly smoked
# 302        Private          Rural              81.84  25.1     never smoked
# 303        Private          Rural             242.30  35.3           smokes
# 304        Private          Rural             102.64  26.4           smokes
#
#      stroke
# 300       0
# 301       0
# 302       0
# 303       0
# 304       0

# %% [markdown]
# ## Get a selection of rows and columns

# %%
df.iloc[10:15][['heart_disease','Residence_type']]
# Out:
#     heart_disease Residence_type
# 10              0          Rural
# 11              1          Rural
# 12              0          Urban
# 13              1          Urban
# 14              1          Urban

# %% [markdown]
# ## Change range index to a category based index

# %%
df_ger = df.set_index('gender')
df_ger.head()
# Out:
#            id   age  hypertension  heart_disease ever_married      work_type  \
# gender
# Male     9046  67.0             0              1          Yes        Private
# Female  51676  61.0             0              0          Yes  Self-employed
# Male    31112  80.0             0              1          Yes        Private
# Female  60182  49.0             0              0          Yes        Private
# Female   1665  79.0             1              0          Yes  Self-employed
#
#        Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# gender
# Male            Urban             228.69  36.6  formerly smoked       1
# Female          Rural             202.21   NaN     never smoked       1
# Male            Rural             105.92  32.5     never smoked       1
# Female          Urban             171.23  34.4           smokes       1
# Female          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# ## Get males only

# %%
df_ger.loc['Male'].head()
# Out:
#            id   age  hypertension  heart_disease ever_married work_type  \
# gender
# Male     9046  67.0             0              1          Yes   Private
# Male    31112  80.0             0              1          Yes   Private
# Male    56669  81.0             0              0          Yes   Private
# Male    53882  74.0             1              1          Yes   Private
# Male     8213  78.0             0              1          Yes   Private
#
#        Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# gender
# Male            Urban             228.69  36.6  formerly smoked       1
# Male            Rural             105.92  32.5     never smoked       1
# Male            Urban             186.21  29.0  formerly smoked       1
# Male            Rural              70.09  27.4     never smoked       1
# Male            Urban             219.84   NaN          Unknown       1

# %%
# remove index
df_ger.reset_index().head()
# Out:
#    gender     id   age  hypertension  heart_disease ever_married  \
# 0    Male   9046  67.0             0              1          Yes
# 1  Female  51676  61.0             0              0          Yes
# 2    Male  31112  80.0             0              1          Yes
# 3  Female  60182  49.0             0              0          Yes
# 4  Female   1665  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## Can still use the numerical based index

# %%
df_ger.iloc[100:105]
# Out:
#            id   age  hypertension  heart_disease ever_married      work_type  \
# gender
# Male    12363  64.0             0              1          Yes       Govt_job
# Female  63973  77.0             0              0          Yes       Govt_job
# Female  45277  74.0             0              0          Yes        Private
# Female   4712  81.0             0              1          Yes  Self-employed
# Female  33175  57.0             0              0          Yes       Govt_job
#
#        Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# gender
# Male            Urban              74.10  28.8          Unknown       1
# Female          Rural             190.32  31.4     never smoked       1
# Female          Rural             231.61  34.6  formerly smoked       1
# Female          Rural              78.70  19.4          Unknown       1
# Female          Urban             110.52  28.5          Unknown       1

# %% [markdown]
# ## Use another index
# - select `private` and `Self-employed`

# %%
df_ind = df.set_index('work_type')
df_ind.head()
# Out:
#                   id  gender   age  hypertension  heart_disease ever_married  \
# work_type
# Private         9046    Male  67.0             0              1          Yes
# Self-employed  51676  Female  61.0             0              0          Yes
# Private        31112    Male  80.0             0              1          Yes
# Private        60182  Female  49.0             0              0          Yes
# Self-employed   1665  Female  79.0             1              0          Yes
#
#               Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# work_type
# Private                Urban             228.69  36.6  formerly smoked       1
# Self-employed          Rural             202.21   NaN     never smoked       1
# Private                Rural             105.92  32.5     never smoked       1
# Private                Urban             171.23  34.4           smokes       1
# Self-employed          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# ## Subsetting the old way

# %%
df[df['work_type'].isin(['Private','Self-employed'])].head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## Subsetting using indexing

# %%
df_ind.loc[['Private','Self-employed']].head()
# Out:
#               id  gender   age  hypertension  heart_disease ever_married  \
# work_type
# Private     9046    Male  67.0             0              1          Yes
# Private    31112    Male  80.0             0              1          Yes
# Private    60182  Female  49.0             0              0          Yes
# Private    56669    Male  81.0             0              0          Yes
# Private    53882    Male  74.0             1              1          Yes
#
#           Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# work_type
# Private            Urban             228.69  36.6  formerly smoked       1
# Private            Rural             105.92  32.5     never smoked       1
# Private            Urban             171.23  34.4           smokes       1
# Private            Urban             186.21  29.0  formerly smoked       1
# Private            Rural              70.09  27.4     never smoked       1

# %% [markdown]
# ## Set multilevel index
# -  set an index with multiple columns

# %%
df_ind2 = df.set_index(['smoking_status','work_type'])
df_ind2.head()
# Out:
#                                   id  gender   age  hypertension  \
# smoking_status  work_type
# formerly smoked Private         9046    Male  67.0             0
# never smoked    Self-employed  51676  Female  61.0             0
#                 Private        31112    Male  80.0             0
# smokes          Private        60182  Female  49.0             0
# never smoked    Self-employed   1665  Female  79.0             1
#
#                                heart_disease ever_married Residence_type  \
# smoking_status  work_type
# formerly smoked Private                    1          Yes          Urban
# never smoked    Self-employed              0          Yes          Rural
#                 Private                    1          Yes          Rural
# smokes          Private                    0          Yes          Urban
# never smoked    Self-employed              0          Yes          Rural
#
#                                avg_glucose_level   bmi  stroke
# smoking_status  work_type
# formerly smoked Private                   228.69  36.6       1
# never smoked    Self-employed             202.21   NaN       1
#                 Private                   105.92  32.5       1
# smokes          Private                   171.23  34.4       1
# never smoked    Self-employed             174.12  24.0       1

# %% [markdown]
# ## Index on the outer level

# %%
df_ind2.loc[['never smoked','formerly smoked']]
# Out:
#                                   id  gender   age  hypertension  \
# smoking_status  work_type
# never smoked    Self-employed  51676  Female  61.0             0
#                 Private        31112    Male  80.0             0
#                 Self-employed   1665  Female  79.0             1
#                 Private        53882    Male  74.0             1
#                 Private        10434  Female  69.0             0
# ...                              ...     ...   ...           ...
# formerly smoked Self-employed  49598    Male  80.0             0
#                 Govt_job       37680    Male  55.0             0
#                 Private        53525  Female  72.0             0
#                 Self-employed  26214  Female  63.0             0
#                 Private        37544    Male  51.0             0
#
#                                heart_disease ever_married Residence_type  \
# smoking_status  work_type
# never smoked    Self-employed              0          Yes          Rural
#                 Private                    1          Yes          Rural
#                 Self-employed              0          Yes          Rural
#                 Private                    1          Yes          Rural
#                 Private                    0           No          Urban
# ...                                      ...          ...            ...
# formerly smoked Self-employed              0          Yes          Urban
#                 Govt_job                   0          Yes          Rural
#                 Private                    0          Yes          Urban
#                 Self-employed              0          Yes          Rural
#                 Private                    0          Yes          Rural
#
#                                avg_glucose_level   bmi  stroke
# smoking_status  work_type
# never smoked    Self-employed             202.21   NaN       1
#                 Private                   105.92  32.5       1
#                 Self-employed             174.12  24.0       1
#                 Private                    70.09  27.4       1
#                 Private                    94.39  22.8       1
# ...                                          ...   ...     ...
# formerly smoked Self-employed             120.03  24.3       0
#                 Govt_job                  108.35  40.8       0
#                 Private                    83.89  33.1       0
#                 Self-employed              75.93  34.7       0
#                 Private                   166.29  25.6       0
#
# [2777 rows x 10 columns]

# %% [markdown]
# ## Index on the outer level and inner level

# %%
df_ind2.loc[[('never smoked','Govt_job'),('smokes','Private')]]
# Out:
#                              id  gender   age  hypertension  heart_disease  \
# smoking_status work_type
# never smoked   Govt_job   14248    Male  48.0             0              0
#                Govt_job    8752  Female  63.0             0              0
#                Govt_job    5111  Female  54.0             1              0
#                Govt_job    4639  Female  69.0             0              0
#                Govt_job   63973  Female  77.0             0              0
# ...                         ...     ...   ...           ...            ...
# smokes         Private    11630  Female  25.0             0              0
#                Private    71957  Female  35.0             0              0
#                Private    24552  Female  44.0             0              0
#                Private    29540    Male  67.0             0              0
#                Private     7293    Male  40.0             0              0
#
#                          ever_married Residence_type  avg_glucose_level   bmi  \
# smoking_status work_type
# never smoked   Govt_job            No          Urban              84.20  29.7
#                Govt_job           Yes          Urban             197.54   NaN
#                Govt_job           Yes          Urban             180.93  27.7
#                Govt_job           Yes          Urban              82.81  28.0
#                Govt_job           Yes          Rural             190.32  31.4
# ...                               ...            ...                ...   ...
# smokes         Private             No          Urban              92.06  25.3
#                Private            Yes          Rural              58.72  40.0
#                Private            Yes          Rural              72.03  37.5
#                Private            Yes          Rural              97.04  26.9
#                Private            Yes          Rural              83.94   NaN
#
#                           stroke
# smoking_status work_type
# never smoked   Govt_job        1
#                Govt_job        1
#                Govt_job        1
#                Govt_job        1
#                Govt_job        1
# ...                          ...
# smokes         Private         0
#                Private         0
#                Private         0
#                Private         0
#                Private         0
#
# [825 rows x 10 columns]
